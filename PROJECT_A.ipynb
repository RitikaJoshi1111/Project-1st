# %% [markdown]
# <a href="https://colab.research.google.com/github/RitikaJoshi1111/Project-1st/blob/main/PROJECT_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/sample_data/HR-Employee-Attrition.csv')
df

# %%
print("number of rows",df.shape[0])
print("number of columns",df.shape[1])
# Out:
# number of rows 1470
# number of columns 35

# %%
pd.set_option("display.max_columns",None)
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], object: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']}

# %%
#Statistical analysis

# %%
#data integrity check

# %%
df.duplicated().sum()#this will check the duplicate value
# Out:
# np.int64(0)

# %%
#Missing Value check
#- Jab data ko analyze karna ho pehle ki kitna incomplete hai

# %%
Missing_value = df.isnull().sum().sort_values(ascending = False)
Percentage_Missing_value = (Missing_value/len(df))*100
print(pd.concat([Missing_value,Percentage_Missing_value],axis = 1,keys =['Missing_value','% Missing Data']))
# Out:
#                           Missing_value  % Missing Data
# Age                                   0             0.0
# Attrition                             0             0.0
# BusinessTravel                        0             0.0
# DailyRate                             0             0.0
# Department                            0             0.0
# DistanceFromHome                      0             0.0
# Education                             0             0.0
# EducationField                        0             0.0
# EmployeeCount                         0             0.0
# EmployeeNumber                        0             0.0
# EnvironmentSatisfaction               0             0.0
# Gender                                0             0.0
# HourlyRate                            0             0.0
# JobInvolvement                        0             0.0
# JobLevel                              0             0.0
# JobRole                               0             0.0
# ...

# %%
plt.figure(figsize = (28,10))
sns.heatmap(df.describe(),linewidth = 0.1,fmt = '0.1f',annot = True,cmap = 'PiYG')
plt.show()

# %%
 #Why It’s Useful:
#- Makes it super readable, especially if you're exporting or showing it in a report.
#- Helps in spotting outliers and understanding distribution patterns quickly.

# %%
df.describe().T.round(3)# t stands for transpose
# Out:
#                            count       mean       std     min      25%  \
# Age                       1470.0     36.924     9.135    18.0    30.00
# DailyRate                 1470.0    802.486   403.509   102.0   465.00
# DistanceFromHome          1470.0      9.193     8.107     1.0     2.00
# Education                 1470.0      2.913     1.024     1.0     2.00
# EmployeeCount             1470.0      1.000     0.000     1.0     1.00
# EmployeeNumber            1470.0   1024.865   602.024     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.722     1.093     1.0     2.00
# HourlyRate                1470.0     65.891    20.329    30.0    48.00
# JobInvolvement            1470.0      2.730     0.712     1.0     2.00
# JobLevel                  1470.0      2.064     1.107     1.0     1.00
# JobSatisfaction           1470.0      2.729     1.103     1.0     2.00
# MonthlyIncome             1470.0   6502.931  4707.957  1009.0  2911.00
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
labels = 'Yes','No'
fig, ax = plt.subplots()
ax.pie(df['Attrition'].value_counts(),labels = labels,radius = 2,autopct = '%2.2f%%',explode = [0.1,0.2],shadow = True,)
plt.show()

# %%
Categories = ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
for i in Categories:
 print(i)
 print(df[i].value_counts())
 print("="*100)
# Out:
# Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ...
# BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ...
# Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ...
# EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# ...
# Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# ...
# JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize = (20,20),facecolor = 'White')
plotnumber = 1
Categories = ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
for i in Categories:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(df[i])
        plt.xlabel(i,fontsize = 20)
        plt.xticks(rotation  = 30)
        plotnumber+=1
plt.tight_layout() #- tight_layout() spacing ko auto-adjust karta hai so that labels overlap na kare.

plt.show()

# %%
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# Education
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64
# ...
# EnvironmentSatisfaction
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64
# ...
# JobInvolvement
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: count, dtype: int64
# ...
# JobSatisfaction
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64
# ...
# RelationshipSatisfaction
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: count, dtype: int64
# ...
# PerformanceRating
# PerformanceRating
# 3    1244
# 4     226
# Name: count, dtype: int64
# ...
# WorkLifeBalance
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64
# ...

# %%
sns.set_palette("hsv")
plt.figure(figsize=(20,20),facecolor = 'White')
plotnumber = 1
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    if plotnumber<=7:
     ax = plt.subplot(3,3,plotnumber)
     sns.countplot(df[i])
     plt.xlabel(i,fontsize = 20)
     plt.xticks(rotation =30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
sns.set_palette("hsv")
plt.figure(figsize=(20,20),facecolor = 'White')
plotnumber = 1
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    if plotnumber<=9:
     ax = plt.subplot(3,3,plotnumber)
     sns.countplot(df[i])
     plt.xlabel(i,fontsize = 20)
     plt.xticks(rotation =30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
#Education level of manpower available

# %%
Labels = 'Bachelor','Master','College','Below College','Doctor'
fig,ax = plt.subplots()
ax.pie(df['Education'].value_counts(),labels = Labels,radius = 2,autopct = '%3.2f%%',explode=[0.1,0.1,0.15,0.2,0.3],shadow = True,)
plt.show()

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
labels ='Research & Development','Sales','Human Resources'
fig,ax = plt.subplots()
ax.pie(df['Department'].value_counts(),labels = labels,radius = 2,autopct = '%3.2f%%',explode=[0.1,0.15,0.2],shadow = True)
plt.show()

# %%
# Let check distribution of education Vs education Field

# %%
pd.crosstab([df.Education],[df.EducationField],margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_43c66_row0_col0, #T_43c66_row1_col0, #T_43c66_row4_col0, #T_43c66_row4_col1, #T_43c66_row4_col2, #T_43c66_row4_col3, #T_43c66_row4_col4, #T_43c66_row4_col5, #T_43c66_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_43c66_row0_col1, #T_43c66_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_43c66_row0_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_43c66_row0_col3 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_43c66_row0_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_43c66_row0_col5 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_43c66_row1_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_43c66_row1_col2 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_43c66_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_43c66_row1_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# ...

# %%
pd.crosstab([df.Department],[df.EducationField],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_75741_row0_col0, #T_75741_row2_col2, #T_75741_row3_col0, #T_75741_row3_col1, #T_75741_row3_col2, #T_75741_row3_col3, #T_75741_row3_col4, #T_75741_row3_col5, #T_75741_row3_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_75741_row0_col1, #T_75741_row0_col2, #T_75741_row0_col3, #T_75741_row0_col4, #T_75741_row0_col5, #T_75741_row0_col6, #T_75741_row1_col0, #T_75741_row1_col2, #T_75741_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_75741_row1_col1 {
#   background-color: #48a366;
#   color: #f1f1f1;
# }
# #T_75741_row1_col3 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_75741_row1_col4 {
#   background-color: #3a9c66;
#   color: #f1f1f1;
# }
# #T_75741_row1_col5 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_75741_row1_col6 {
#   background-color: #5cae66;
#   color: #f1f1f1;
# }
# #T_75741_row2_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_75741_row2_col3 {
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['JobRole'])
plt.xticks(rotation = 45)
plt.show()

# %%
pd.crosstab([df.JobRole],[df.Department],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_b3980_row0_col0, #T_b3980_row0_col2, #T_b3980_row1_col1, #T_b3980_row1_col2, #T_b3980_row1_col3, #T_b3980_row2_col0, #T_b3980_row2_col2, #T_b3980_row4_col0, #T_b3980_row4_col2, #T_b3980_row5_col0, #T_b3980_row5_col2, #T_b3980_row6_col0, #T_b3980_row6_col2, #T_b3980_row7_col0, #T_b3980_row7_col1, #T_b3980_row8_col0, #T_b3980_row8_col1 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_b3980_row0_col1 {
#   background-color: #8600ff;
#   color: #f1f1f1;
# }
# #T_b3980_row0_col3, #T_b3980_row3_col1 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_b3980_row1_col0 {
#   background-color: #ffc400;
#   color: #000000;
# }
# #T_b3980_row2_col1 {
#   background-color: #0033ff;
#   color: #f1f1f1;
# }
# #T_b3980_row2_col3 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_b3980_row3_col0 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_b3980_row3_col2, #T_b3980_row5_col1 {
#   background-color: #cd00ff;
# ...

# %%
plt.figure(figsize = (12,10))
data = pd.crosstab(df['JobRole'],df['Attrition'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar',stacked = True,color=['green','red'],figsize=(12,8))
plt.title('Attrition as per job Role',fontsize = 20)
plt.xlabel('Job Role',fontsize=15)
plt.show()

# %%
pd.crosstab([df.JobRole,df.Department],[df.Attrition],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_db26b_row0_col0, #T_db26b_row6_col2 {
#   background-color: #c200ff;
#   color: #f1f1f1;
# }
# #T_db26b_row0_col1 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_db26b_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_db26b_row1_col0 {
#   background-color: #ff00e0;
#   color: #f1f1f1;
# }
# #T_db26b_row1_col1, #T_db26b_row7_col2, #T_db26b_row10_col2 {
#   background-color: #fe00ff;
#   color: #f1f1f1;
# }
# #T_db26b_row1_col2, #T_db26b_row4_col2 {
#   background-color: #ff00e5;
#   color: #f1f1f1;
# }
# #T_db26b_row2_col0 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_db26b_row2_col1 {
#   background-color: #0028ff;
#   color: #f1f1f1;
# }
# #T_db26b_row2_col2 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_db26b_row3_col0, #T_db26b_row3_col1, #T_db26b_row3_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_db26b_row4_col0, #T_db26b_row10_col0 {
# ...

# %%
Numeric=['Age', 'DailyRate', 'DistanceFromHome',
 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
 'RelationshipSatisfaction','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#Numeric

# %%
#Age vs Attrition

# %%
plt.subplots(figsize=(12,6))
sns.countplot(df['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.set_palette('hsv')
plt.subplots(figsize=(18,8))
sns.countplot(x='Age',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = df.TotalWorkingYears,y = df.MonthlyIncome)
plt.xlabel('Total_Working_Years',fontsize=20)
plt.ylabel('Monthly_income',fontsize=20)
plt.title("Total_Working_years vs Monthly_income",fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 8))
sns.barplot(x='TotalWorkingYears', y='MonthlyIncome', data=df)
plt.xlabel('Total_Working_Years', fontsize=20)
plt.ylabel('Monthly_income', fontsize=20)
plt.title("Total_Working_years vs Monthly_income", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='MonthlyIncome',data = df)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
#Encoding Categorical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df.head(10)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
# 5   32          0  Travel_Frequently       1005  Research & Development
# 6   59          0      Travel_Rarely       1324  Research & Development
# 7   30          0      Travel_Rarely       1358  Research & Development
# 8   38          0  Travel_Frequently        216  Research & Development
# 9   36          0      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
#Dropping Unnecessay column

# %%
df.drop(["EmployeeCount", "EmployeeNumber", "Over18", "StandardHours"], inplace=True, errors='ignore')
df

# %%
df.shape
# Out:
# (1470, 35)

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
def ordinal_endode(df, column):
    df[column] = OE.fit_transform(df[column])
    return df

OE_col = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
df = ordinal_endode(df, OE_col)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1             2.0       1102         2.0                 1
# 1   49          0             1.0        279         1.0                 8
# 2   37          1             2.0       1373         1.0                 2
# 3   33          0             1.0       1392         1.0                 3
# 4   27          0             2.0        591         1.0                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2             1.0              1               1
# 1          1             1.0              1               2
# 2          2             4.0              1               4
# 3          4             1.0              1               5
# 4          1             3.0              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2     0.0          94               3         2
# ...

# %%
#outlier Detection and Removal

# %%
plt.figure(figsize = (20,30),facecolor = 'white')
plotnumber = 1
for column in Numeric:
  if plotnumber<=28:
    ax = plt.subplot(7,4,plotnumber)
    sns.boxplot(df[column],color='g')
    plt.xlabel(column,fontsize = 20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numeric:
    if plotnumber<=28:
        ax=plt.subplot(7,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df[Numeric]))
threshhold = 3
df1 = df[(z<3).all(axis = 1)]
print ("Shape of the dataframe before removing outliers:",df.shape)
print ("Shape of the dataframe after removing outliers:",df1.shape)
print ("percentage od data lost post outlier removal:",(df.shape[0]-df1.shape[0])/df.shape[0]*100)
df = df1.copy()
# Out:
# Shape of the dataframe before removing outliers: (1470, 35)
# Shape of the dataframe after removing outliers: (1387, 35)
# percentage od data lost post outlier removal: 5.646258503401361

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((1470-1387)/1470)*100,'%')
# Out:
# Percentage Data Loss : 5.646258503401361 %

# %%
#skewness of feature
df.skew(numeric_only=True)
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EmployeeCount               0.000000
# EmployeeNumber              0.018931
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# ...

# %%
# Splitting data in target and dependent feature
X = df.drop(['Attrition'], axis =1)
Y = df['Attrition']

# %%
# Transforming  skew data using power transform
from sklearn.preprocessing import power_transform
X = X.drop('Over18', axis=1)
df_transformed = power_transform(X)
df_transformed = pd.DataFrame(df_transformed, columns=X.columns)
df_transformed.skew()
# Out:
# Age                        -0.004079
# BusinessTravel             -0.960583
# DailyRate                  -0.199742
# Department                  0.015095
# DistanceFromHome           -0.008149
# Education                  -0.103747
# EducationField             -0.008642
# EmployeeCount               0.000000
# EmployeeNumber             -0.287518
# EnvironmentSatisfaction    -0.205472
# Gender                     -0.417296
# HourlyRate                 -0.105678
# JobInvolvement             -0.018801
# JobLevel                    0.110769
# JobRole                    -0.337641
# JobSatisfaction            -0.217730
# MaritalStatus              -0.158253
# MonthlyIncome               0.027700
# MonthlyRate                -0.176560
# NumCompaniesWorked          0.016175
# OverTime                    0.954751
# PercentSalaryHike           0.112128
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.191407
# StandardHours               0.000000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make a safe copy
df = df1.copy()

# 1) Convert Attrition to numeric (handles 'Yes/No', 'Y/N', 'True/False', '1/0', extra spaces)
df['Attrition'] = (
    df['Attrition'].astype(str).str.strip().str.lower()
      .map({'yes':1,'no':0,'y':1,'n':0,'true':1,'false':0,'1':1,'0':0})
)

# 2) Keep only numeric columns (works on any pandas version) and drop rows with missing target
df_num = df.select_dtypes(include=[np.number]).dropna(subset=['Attrition'])

# 3) Correlation with Attrition and plot
corr = df_num.corr()['Attrition'].drop('Attrition').sort_values(ascending=False)

plt.figure(figsize=(18,6))
corr.plot(kind='bar')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Correlation with Attrition', fontsize=15)
plt.title('Correlation of Features with Target Variable Attrition', fontsize=18)
plt.tight_layout()
plt.show()

# %%
cols = [
    "Age", "BusinessTravel", "DailyRate", "Department", "DistanceFromHome",
    "Education", "EducationField", "EnvironmentSatisfaction", "Gender", "HourlyRate",
    "JobInvolvement", "JobLevel", "JobRole", "JobSatisfaction", "MaritalStatus",
    "MonthlyIncome", "MonthlyRate", "NumCompaniesWorked", "OverTime", "PercentSalaryHike",
    "RelationshipSatisfaction", "StockOptionLevel", "TotalWorkingYears", "TrainingTimesLastYear",
    "WorkLifeBalance", "YearsAtCompany", "YearsInCurrentRole", "YearsSinceLastPromotion",
    "YearsWithCurrManager"
]

# Correlation matrix sirf in columns ki
corr_matrix = df[cols].corr()

# Agar kisi column me NaN hai to hata do
corr_matrix = corr_matrix.dropna(axis=0, how='all').dropna(axis=1, how='all')

# Output dekhna
print(corr_matrix)
# Out:
#                                Age  BusinessTravel  DailyRate  Department  \
# Age                       1.000000        0.022340   0.021946   -0.038242
# BusinessTravel            0.022340        1.000000  -0.004606   -0.003521
# DailyRate                 0.021946       -0.004606   1.000000   -0.005398
# Department               -0.038242       -0.003521  -0.005398    1.000000
# DistanceFromHome         -0.011265       -0.032873  -0.008171    0.023919
# Education                 0.198502       -0.010560  -0.018442    0.012846
# EducationField           -0.032676        0.022576   0.040645    0.013432
# EnvironmentSatisfaction   0.014098        0.001183   0.033123   -0.014540
# Gender                   -0.039430       -0.025364  -0.005242   -0.030618
# HourlyRate                0.025465        0.025424   0.014279   -0.002412
# JobInvolvement            0.036424        0.028261   0.048004   -0.024040
# JobLevel                  0.453902        0.018996   0.022978    0.126809
# ...

# %%
upper_triangle = np.triu(df_transformed.corr())
plt.figure(figsize=(25,15))
sns.heatmap(df_transformed.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f',
            annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'Attrition' to numeric
df1['Attrition'] = df1['Attrition'].map({'Yes': 1, 'No': 0})

# Convert other categorical features to numeric
df_encoded = pd.get_dummies(df1, drop_first=True)

# Get correlation with Attrition
corr = df_encoded.corr(numeric_only=True)['Attrition'].drop('Attrition')

# Plot
plt.figure(figsize=(18,6))
corr.sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Correlation with Attrition', fontsize=15)
plt.title('Correlation of Features with Target Variable Attrition', fontsize=18)
plt.show()

# %%
from imblearn.over_sampling import SMOTE

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# Attrition
# 1    1158
# 0    1158
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=21)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(21))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1551, 21)
# Training target vector size: (1551,)
# Test feature matrix size: (765, 21)
# Test target vector size: (765,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=242, test_size=.33)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.873202614379085
#
#
# Confusion matrix of Logistics Regression :
#  [[317  51]
#  [ 46 351]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       368
#            1       0.87      0.88      0.88       397
#
#     accuracy                           0.87       765
#    macro avg       0.87      0.87      0.87       765
# weighted avg       0.87      0.87      0.87       765

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(30):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.33916467937944555
# RMSE value for k=  2 is: 0.2914915440650687
# RMSE value for k=  3 is: 0.3651483716701107
# RMSE value for k=  4 is: 0.34108630767160053
# RMSE value for k=  5 is: 0.3877199986918664
# RMSE value for k=  6 is: 0.3542459542160381
# RMSE value for k=  7 is: 0.3791976393296807
# RMSE value for k=  8 is: 0.3704792868174742
# RMSE value for k=  9 is: 0.40260589075170505
# RMSE value for k=  10 is: 0.3722392933359776
# RMSE value for k=  11 is: 0.3960590171906697
# RMSE value for k=  12 is: 0.3860305788964616
# RMSE value for k=  13 is: 0.39770583933420295
# RMSE value for k=  14 is: 0.37747007845751024
# RMSE value for k=  15 is: 0.3960590171906697
# RMSE value for k=  16 is: 0.3791976393296807
# RMSE value for k=  17 is: 0.39107694443752145
# RMSE value for k=  18 is: 0.3791976393296807
# RMSE value for k=  19 is: 0.39934587037179503
# RMSE value for k=  20 is: 0.38262936212236764
# RMSE value for k=  21 is: 0.4009791936316524
# ...

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(30), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %%
model=[
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 2),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.918954248366013
#
#
# Confusion matrix :
#  [[341  27]
#  [ 35 362]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       368
#            1       0.93      0.91      0.92       397
#
#     accuracy                           0.92       765
#    macro avg       0.92      0.92      0.92       765
# weighted avg       0.92      0.92      0.92       765
#
#
#
# ...
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.8614379084967321
#
#
# Confusion matrix :
#  [[321  47]
#  [ 59 338]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       368
#            1       0.88      0.85      0.86       397
#
#     accuracy                           0.86       765
# ...
